# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
data = pd.read_csv(r"data.csv")
print(data)
# Out:
#         N   P   K  temperature   humidity        ph    rainfall   label
# 0      90  42  43    20.879744  82.002744  6.502985  202.935536    rice
# 1      85  58  41    21.770462  80.319644  7.038096  226.655537    rice
# 2      60  55  44    23.004459  82.320763  7.840207  263.964248    rice
# 3      74  35  40    26.491096  80.158363  6.980401  242.864034    rice
# 4      78  42  42    20.130175  81.604873  7.628473  262.717340    rice
# ...   ...  ..  ..          ...        ...       ...         ...     ...
# 2195  107  34  32    26.774637  66.413269  6.780064  177.774507  coffee
# 2196   99  15  27    27.417112  56.636362  6.086922  127.924610  coffee
# 2197  118  33  30    24.131797  67.225123  6.362608  173.322839  coffee
# 2198  117  32  34    26.272418  52.127394  6.758793  127.175293  coffee
# 2199  104  18  30    23.603016  60.396475  6.779833  140.937041  coffee
#
# [2200 rows x 8 columns]

# %%
data = data.drop(columns=['rainfall'])
print(data)

# %%
sns.heatmap(data.isnull())
# Out:
# <Axes: >

# %%
x= data.iloc[:,:-1].values
y= data.iloc[:,-1].values
print(x)
print(y)
# Out:
# [[ 90.          42.          43.          20.87974371  82.00274423
#     6.50298529]
#  [ 85.          58.          41.          21.77046169  80.31964408
#     7.03809636]
#  [ 60.          55.          44.          23.00445915  82.3207629
#     7.84020714]
#  ...
#  [118.          33.          30.          24.13179691  67.22512329
#     6.36260785]
#  [117.          32.          34.          26.2724184   52.12739421
#     6.75879255]
#  [104.          18.          30.          23.60301571  60.39647474
#     6.77983261]]
# ['rice' 'rice' 'rice' ... 'coffee' 'coffee' 'coffee']

# %%
from sklearn.model_selection import train_test_split

# %%
x_train, x_test,y_train, y_test = train_test_split(x,y , test_size=0.20)

# %%
from sklearn.naive_bayes import GaussianNB
gnb = GaussianNB()
gnb.fit(x_train,y_train)
# Out:
# GaussianNB()

# %%
from sklearn.metrics import classification_report

# %%
knncr = classification_report(y_test, gnb.predict(x_test))
print(knncr)
# Out:
#               precision    recall  f1-score   support
#
#        apple       1.00      1.00      1.00        16
#       banana       1.00      1.00      1.00        16
#    blackgram       0.84      0.94      0.89        17
#     chickpea       1.00      1.00      1.00        21
#      coconut       1.00      1.00      1.00        19
#       coffee       0.95      1.00      0.98        21
#       cotton       1.00      1.00      1.00        20
#       grapes       1.00      1.00      1.00        21
#         jute       0.85      0.50      0.63        22
#  kidneybeans       1.00      1.00      1.00        20
#       lentil       0.96      0.86      0.91        29
#        maize       1.00      1.00      1.00        21
#        mango       1.00      1.00      1.00        14
#    mothbeans       0.95      1.00      0.98        20
#     mungbean       1.00      1.00      1.00        24
#    muskmelon       1.00      1.00      1.00        23
#       orange       1.00      1.00      1.00        16
#       papaya       1.00      1.00      1.00        19
#   pigeonpeas       1.00      1.00      1.00        20
#  pomegranate       1.00      1.00      1.00        20
#         rice       0.67      0.91      0.77        22
#   watermelon       1.00      1.00      1.00        19
#
#     accuracy                           0.96       440
#    macro avg       0.96      0.96      0.96       440
# weighted avg       0.96      0.96      0.96       440

# %%
from sklearn.linear_model import LogisticRegression
lr = LogisticRegression(max_iter=2000)
lr.fit(x_train,y_train)
# Out:
# LogisticRegression(max_iter=2000)

# %%
knncr = classification_report(y_test, lr.predict(x_test))
print(knncr)
# Out:
#               precision    recall  f1-score   support
#
#        apple       0.89      1.00      0.94        16
#       banana       1.00      1.00      1.00        16
#    blackgram       0.67      0.82      0.74        17
#     chickpea       1.00      1.00      1.00        21
#      coconut       1.00      1.00      1.00        19
#       coffee       0.95      1.00      0.98        21
#       cotton       0.95      1.00      0.98        20
#       grapes       1.00      0.90      0.95        21
#         jute       0.80      0.73      0.76        22
#  kidneybeans       1.00      1.00      1.00        20
#       lentil       0.96      0.76      0.85        29
#        maize       1.00      0.95      0.98        21
#        mango       1.00      1.00      1.00        14
#    mothbeans       0.83      0.75      0.79        20
#     mungbean       0.92      1.00      0.96        24
#    muskmelon       0.92      0.96      0.94        23
#       orange       1.00      1.00      1.00        16
#       papaya       1.00      1.00      1.00        19
#   pigeonpeas       0.82      0.90      0.86        20
#  pomegranate       1.00      1.00      1.00        20
#         rice       0.78      0.82      0.80        22
#   watermelon       0.94      0.89      0.92        19
#
#     accuracy                           0.93       440
#    macro avg       0.93      0.93      0.93       440
# weighted avg       0.93      0.93      0.92       440

# %%
input_2 = [[20,20,20,30,80,7]]
ypp = gnb.predict(input_2)

print(ypp)
# Out:
# ['mungbean']

# %%
import joblib

# %%
joblib.dump(gnb,'crop_predict.joblib')
# Out:
# ['crop_predict.joblib']
